# %% [markdown]
# <a href="https://colab.research.google.com/github/konqr/gan/blob/master/gan_MIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install -U -q PyDrive
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
# choose a local (colab) directory to store the data.
local_download_path = os.path.expanduser('~/data/test')
try:
  os.makedirs(local_download_path)
except: pass

# 2. Auto-iterate using the query syntax
#    https://developers.google.com/drive/v2/web/search-parameters
file_list = drive.ListFile(
    {'q': "'1qPw_zV8hl3Wv0IM31mlA55xiMQYhB0Pk' in parents"}).GetList()

for f in file_list:
  # 3. Create & download by id.
  print('title: %s, id: %s' % (f['title'], f['id']))
  fname = os.path.join(local_download_path, f['title'])
  print('downloading to {}'.format(fname))
  f_ = drive.CreateFile({'id': f['id']})
  f_.GetContentFile(fname)


with open(fname, 'r') as f:
  print(f.read())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# title: 0009_05934.pgm, id: 1dT6aAmachkCx4dQVF7-Q5mYF6IYsE_-1
# downloading to /root/data/test/0009_05934.pgm
# title: 0009_05932.pgm, id: 1kf5xNooBbhh4hBYbSQVkDke7bK1x8TLJ
# downloading to /root/data/test/0009_05932.pgm
# title: 0009_06028.pgm, id: 1YdpHnMCUrMXJ_Jzrc714wnsCw0Vwu6Dz
# downloading to /root/data/test/0009_06028.pgm
# title: 0009_05936.pgm, id: 1GOti_k-zzOihRQdMp5Tm85DhNIkqtcYh
# downloading to /root/data/test/0009_05936.pgm
# title: 0009_06042.pgm, id: 1rk8qkfbRm8219N5X4N-dNsypWTwtQxMW
# downloading to /root/data/test/0009_06042.pgm
# title: 0009_05925.pgm, id: 1bI2BuAk0brxenZYPNoffTnqZkzR1X3xG
# downloading to /root/data/test/0009_05925.pgm
# title: 0009_05919.pgm, id: 1yXJNdTMKE-lXQq_XwwriuTcAEVPOy4il
# downloading to /root/data/test/0009_05919.pgm
# title: 0009_05914.pgm, id: 1h5PEoi0k9h-kY-UaaEyLTyvi4vI_llCQ
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install -U -q PyDrive
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# choose a local (colab) directory to store the data.
local_download_path = os.path.expanduser('~/data/training-synthetic')
try:
  os.makedirs(local_download_path)
except: pass

# 2. Auto-iterate using the query syntax
#    https://developers.google.com/drive/v2/web/search-parameters
file_list = drive.ListFile(
    {'q': "'1bMkvku379mr2QVPsopBdTnLiON_Z57dO' in parents"}).GetList()

for f in file_list:
  # 3. Create & download by id.
  print('title: %s, id: %s' % (f['title'], f['id']))
  fname = os.path.join(local_download_path, f['title'])
  print('downloading to {}'.format(fname))
  f_ = drive.CreateFile({'id': f['id']})
  f_.GetContentFile(fname)


with open(fname, 'r') as f:
  print(f.read())

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install -U -q PyDrive
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

import tensorflow as tf
import glob
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os
from PIL import Image
# !pip install -U -q skimage
from skimage.measure import block_reduce

def load_dataset():
	train_set_x_orig = []
	train_set_y_orig = []
	test_set_x_orig = []
	test_set_y_orig = []
	i=1
	path = os.path.expanduser('~/data/training-synthetic')
	for infile in glob.glob(path + "/*.pgm"):
		temp = np.array(Image.open(infile))
		temp = block_reduce(temp, block_size=(6, 6), func=np.mean)
		train_set_x_orig = np.append(train_set_x_orig,temp)
		print(i)
		i = i+1
		train_set_y_orig = np.append(train_set_y_orig,np.int(infile[30:34])) # your train set labels
	path = os.path.expanduser('~/data/test')
	for filename in glob.glob(path+"/*.pgm"):
		im = Image.open(filename)
		temp = np.array(im.resize((200,200), Image.ANTIALIAS))
		temp = block_reduce(temp, block_size=(6, 6), func=np.mean)
		test_set_x_orig = np.append(test_set_x_orig,temp) # your test set features
		test_set_y_orig = np.append(test_set_y_orig,np.int(filename[16:20])) # your test set labels

	classes = np.arange(0,10) # the list of classes
	print(train_set_x_orig.shape)
	train_set_x_orig = np.reshape(train_set_x_orig,(np.int(len(train_set_x_orig)/1156),34,34))
	test_set_x_orig = np.reshape(test_set_x_orig,(np.int(len(test_set_x_orig)/1156),34,34))
	train_set_y_orig = np.asarray(train_set_y_orig)
	train_set_y_orig = np.reshape((train_set_y_orig),(1, train_set_y_orig.shape[0]))
	test_set_y_orig = np.asarray(test_set_y_orig)
	test_set_y_orig = np.reshape((test_set_y_orig),(1, test_set_y_orig.shape[0]))
	
	return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

def xavier_init(size):
	in_dim = size[0]
	xavier_stddev = 1. / tf.sqrt(in_dim / 2.)
	return tf.random_normal(shape=size, stddev=xavier_stddev)


X = tf.placeholder(tf.float32, shape=[None, 1156])

D_W1 = tf.Variable(xavier_init([1156, 128]))
D_b1 = tf.Variable(tf.zeros(shape=[128]))

D_W2 = tf.Variable(xavier_init([128, 1]))
D_b2 = tf.Variable(tf.zeros(shape=[1]))

theta_D = [D_W1, D_W2, D_b1, D_b2]


Z = tf.placeholder(tf.float32, shape=[None, 100])

G_W1 = tf.Variable(xavier_init([100, 128]))
G_b1 = tf.Variable(tf.zeros(shape=[128]))

G_W2 = tf.Variable(xavier_init([128, 1156]))
G_b2 = tf.Variable(tf.zeros(shape=[1156]))

theta_G = [G_W1, G_W2, G_b1, G_b2]


def sample_Z(m, n):
	return np.random.uniform(-1., 1., size=[m, n])


def generator(z):
	G_h1 = tf.nn.relu(tf.matmul(z, G_W1) + G_b1)
	G_log_prob = tf.matmul(G_h1, G_W2) + G_b2
	G_prob = tf.nn.sigmoid(G_log_prob)

	return G_prob


def discriminator(x):
	D_h1 = tf.nn.relu(tf.matmul(x, D_W1) + D_b1)
	D_logit = tf.matmul(D_h1, D_W2) + D_b2
	D_prob = tf.nn.sigmoid(D_logit)

	return D_prob, D_logit


def plot(samples):
	fig = plt.figure(figsize=(4, 4))
	gs = gridspec.GridSpec(4, 4)
	gs.update(wspace=0.05, hspace=0.05)

	for i, sample in enumerate(samples):
		ax = plt.subplot(gs[i])
		plt.axis('off')
		ax.set_xticklabels([])
		ax.set_yticklabels([])
		ax.set_aspect('equal')
		plt.imshow(sample.reshape(34,34))

	return fig


G_sample = generator(Z)
D_real, D_logit_real = discriminator(X)
D_fake, D_logit_fake = discriminator(G_sample)

# D_loss = -tf.reduce_mean(tf.log(D_real) + tf.log(1. - D_fake))
# G_loss = -tf.reduce_mean(tf.log(D_fake))

# Alternative losses:
# -------------------
D_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_logit_real, labels=tf.ones_like(D_logit_real)))
D_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_logit_fake, labels=tf.zeros_like(D_logit_fake)))
D_loss = D_loss_real + D_loss_fake
G_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_logit_fake, labels=tf.ones_like(D_logit_fake)))

D_solver = tf.train.AdamOptimizer().minimize(D_loss, var_list=theta_D)
G_solver = tf.train.AdamOptimizer().minimize(G_loss, var_list=theta_G)

mb_size = 128
Z_dim = 100

#mnist = input_data.read_data_sets('../../MNIST_data', one_hot=True)
train_set_x_orig,_,_,_,_ = load_dataset()

sess = tf.Session()
sess.run(tf.global_variables_initializer())

if not os.path.exists('out/'):
	os.makedirs('out/')

i = 0

for it in range(1000000):
	if it % 100 == 0:
		samples = sess.run(G_sample, feed_dict={Z: sample_Z(16, Z_dim)})

		fig = plot(samples)
		plt.savefig('out/{}.png'.format(str(i).zfill(3)), bbox_inches='tight')
		i += 1
		plt.close(fig)
	
	X_mb = train_set_x_orig[np.random.choice(train_set_x_orig.shape[0],mb_size)][:][:].reshape((mb_size,1156))

	_, D_loss_curr = sess.run([D_solver, D_loss], feed_dict={X: X_mb, Z: sample_Z(mb_size, Z_dim)})
	_, G_loss_curr = sess.run([G_solver, G_loss], feed_dict={Z: sample_Z(mb_size, Z_dim)})

	if it % 100 == 0:
		print('Iter: {}'.format(it))
		print('D loss: {:.4}'. format(D_loss_curr))
		print('G_loss: {:.4}'.format(G_loss_curr))
		print()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# ...

# %%
infile = os.path.expanduser('~/data/training-synthetic/0001_-16_0_0_60_0_1.pgm')
temp = np.array(Image.open(infile))
temp = block_reduce(temp, block_size=(6, 6), func=np.mean)
print(temp.shape)
plot(temp)
